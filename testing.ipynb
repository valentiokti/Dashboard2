# %%
import requests
import pandas as pd

# %%
url1 = "https://www.solofleet.com/api/vehiclelivequeryvehiclejson"
params1 = {
    "username": "kristal",
    "password": "transport",
    "type": "json",
    "vehicleid": "KR002"
}

response1 = requests.get(url1, params=params1)

if response1.status_code == 200:
    data_all_vehicle = response1.json()
else:
    print("Gagal")

# %%
data_all_vehicle
df = pd.DataFrame(data_all_vehicle)

# %%
df
# Out:
#    vehicleid                                       alias  \
# 0       KR25                 KTI-024 - Unit - 24 - Ahmad
# 1      KT119                 KTI-025 - Unit - 25 - Happy
# 2      KR001                  KTI-001 - B9336UXY - Cecep
# 3      KR003                   KTI-002 - B9372UXY - Rico
# 4      KR002                 KTI-003 - B9371UXY - Hendra
# 5      KR004                   KTI-004 - B9572UXY - Dede
# 6      KR005                 KTI-005 - B9629UXY - Sunggu
# 7      KR006                 KTI-006 - B9605UXY - Antoni
# 8      KR007                 KTI-007 - B9628UXY - Yani M
# 9      KTI18                KTI-008 - B9571UXY - Solihin
# 10      KR11                  KTI-009 - B9731UXY - Hendi
# 11      KR10                 KTI-010 - B9986UEX - Hamdan
# 12     KR009                   KTI-011 - B9973UEX - Bari
# 13      KR12                 KTI-012 - B9036UEY - GomGom
# 14      KR13  KTI-013 - B9796UXY - Sudirman (test solar)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   vehicleid             28 non-null     object
#  1   alias                 28 non-null     object
#  2   gpstime               28 non-null     object
#  3   latitude              28 non-null     float64
#  4   longtitude            28 non-null     float64
#  5   speed                 28 non-null     int64
#  6   course                28 non-null     int64
#  7   streetName            28 non-null     object
#  8   subDistrict           28 non-null     object
#  9   district              28 non-null     object
#  10  city                  28 non-null     object
#  11  province              28 non-null     object
#  12  engineStatus          28 non-null     object
#  13  iP4Compressor         28 non-null     object
#  14  temperature1          28 non-null     float64
# ...
